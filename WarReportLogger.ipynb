# %%
from WarReportLogger import main_logger

# %%
import pandas as pd
import datetime 
import numpy as np
from collections import defaultdict
import operator

# %%
df2 = pd.read_csv('segoutput.csv',index_col=False)
df2 = df2.set_index(['segment_id'])
df1 = pd.read_csv('segoutput_ref.csv',index_col=False)
df1 = df1.set_index(['segment_id'])
df1
# Out:
#               id   latitude  longitude  \
# segment_id
# 3655223        0  45.385230 -73.970126
# 4373377        1  45.384464 -73.968663
# 8840701        2  45.384433 -73.966737
# 9349111        3  45.384506 -73.968986
# 821292         4  45.427194 -73.968512
# 4305613        5  45.427031 -73.968420
# 2492803        6  45.436715 -73.968369
# 2196976        7  45.426561 -73.968267
# 1019465        8  45.425414 -73.968082
# 7050243        9  45.427516 -73.968755
# 7778864       10  45.426946 -73.968423
# 2188255       11  45.423602 -73.967769
# 9316675       12  45.426861 -73.968377
# 9772929       13  45.426459 -73.968291
# 5003401       14  45.497927 -74.002722
# 9451251       15  45.533635 -74.006237
# 4530219       16  45.571800 -73.979915
# 4035578       17  45.571575 -73.979777
# 7180817       18  45.640010 -73.989161
# 9910818       19  45.648772 -73.988791
# 4616988       20  45.628681 -73.986082
# 5624984       21  45.396557 -73.964414
# 7930686       22  45.382198 -73.965810
# 4302537       23  45.385354 -73.992450
# 7605315       24  45.395035 -73.982964
# 7733739       25  45.394542 -73.984151
# 9490953       26  45.391863 -73.970518
# 7264173       27  45.384129 -73.979088
# 9625097       28  45.386340 -73.999024
# 4791945       29  45.385333 -74.013862
# ...          ...        ...        ...
# 10469430    2633  45.682298 -73.497313
# 10185152    2634  45.670163 -73.807813
# 10622821    2635  45.683526 -73.788179
# 11153275    2636  45.686032 -73.514259
# 10288544    2637  45.687443 -73.870466
# 11153264    2638  45.679536 -73.518164
# 10324310    2639  45.687713 -73.870344
# 8109705     2640  45.687441 -73.635060
# 10469499    2641  45.690242 -73.498111
# 10185142    2642  45.695911 -73.807002
# 10346477    2643  45.694928 -73.684237
# 10623568    2644  45.695147 -73.612191
# 10623573    2645  45.694810 -73.619061
# 10469484    2646  45.690503 -73.514528
# 10469512    2647  45.686793 -73.526054
# 10347137    2648  45.698345 -73.869087
# 10349005    2649  45.698427 -73.869441
# 10842995    2650  45.698683 -73.502276
# 10290118    2651  45.698821 -73.913629
# 10348320    2652  45.700313 -73.865303
# 10347396    2653  45.698322 -73.869188
# 10250291    2654  45.699253 -73.899010
# 11073761    2655  45.710629 -73.663700
# 10249873    2656  45.701396 -73.483363
# 10346424    2657  45.715031 -73.698771
# 10639232    2658  45.714829 -73.678903
# 10346530    2659  45.714401 -73.669801
# 10346565    2660  45.713811 -73.671236
# 10482772    2661  45.721339 -73.479157
# 11047612    2662  45.734293 -73.624636
#
#                                                          name          type  \
# segment_id
# 3655223                     Boul. Pincourt hill:  [UNCLAIMED]     UNCLAIMED
# 4373377                          Pincourt Punch:  [UNCLAIMED]     UNCLAIMED
# 8840701                           Full fat loop:  [UNCLAIMED]     UNCLAIMED
# 9349111     Boul. Pincourt bike path + rue du Rocher:  [UN...     UNCLAIMED
# 821292                           Dave's hill:  [Eoin Craigie]  Eoin Craigie
# 4305613                          Warp Dragon:  [Eoin Craigie]  Eoin Craigie
# 2492803               Senneville Hill - West:  [Eoin Craigie]  Eoin Craigie
# 2196976                     Senneville Climb:  [Eoin Craigie]  Eoin Craigie
# 1019465                           Apple Muur:  [Eoin Craigie]  Eoin Craigie
# 7050243                      Dave'hill court:  [Eoin Craigie]  Eoin Craigie
# 7778864     WCG : Interval 7 : Senneville Hill:  [Eoin Cra...  Eoin Craigie
# 2188255                           GLOCK MUUR:  [Eoin Craigie]  Eoin Craigie
# 9316675            PS40 : KOM 3 : Senneville:  [Eoin Craigie]  Eoin Craigie
# 9772929                          hilly billy:  [Eoin Craigie]  Eoin Craigie
# 5003401                           Oka E-O / O-E:  [UNCLAIMED]     UNCLAIMED
# 9451251     Oka Square Loop (North) via Montee du Village ...     UNCLAIMED
# 4530219     Sprint final vers la cabane a sucre:  [UNCLAIMED]     UNCLAIMED
# 4035578     lalande-bois de rivière-freniere-lalande:  [UN...     UNCLAIMED
# 7180817           Loop Saint et Ange "Official":  [UNCLAIMED]     UNCLAIMED
# 9910818          Petit Sprint de belle asphalte:  [UNCLAIMED]     UNCLAIMED
# 4616988                           The Mira Hood:  [UNCLAIMED]     UNCLAIMED
# 5624984                     Ile Perrot Warm-up!:  [UNCLAIMED]     UNCLAIMED
# 7930686                           Nitrous Oxide:  [UNCLAIMED]     UNCLAIMED
# 4302537                         Traversier Trot:  [UNCLAIMED]     UNCLAIMED
# 7605315                  Blvd Perrot East 1.5km:  [UNCLAIMED]     UNCLAIMED
# 7733739     WCG : Ferries Loop : Terrasse Sprint : 7e to T...     UNCLAIMED
# 9490953            la 20 jusquau chemin Duhamel:  [UNCLAIMED]     UNCLAIMED
# 7264173                          LT Power-Climb:  [UNCLAIMED]     UNCLAIMED
# 9625097     Autoroute 20 : Ile-Perot→Vaudreuil:  [Mike Sants]    Mike Sants
# 4791945           Rue de l'Hôtel de Ville Climb:  [UNCLAIMED]     UNCLAIMED
# ...                                                       ...           ...
# 10469430           La boucle du Parc nature sud:  [UNCLAIMED]     UNCLAIMED
# 10185152                            Paul Albert:  [UNCLAIMED]     UNCLAIMED
# 10622821                           Test Vitesse:  [UNCLAIMED]     UNCLAIMED
# 11153275                 dans le champ de la 40:  [UNCLAIMED]     UNCLAIMED
# 10288544                              Lala loop:  [UNCLAIMED]     UNCLAIMED
# 11153264           dans le champ de la 40 ouest:  [UNCLAIMED]     UNCLAIMED
# 10324310                              Pama loop:  [UNCLAIMED]     UNCLAIMED
# 8109705                          Tour Est Laval:  [UNCLAIMED]     UNCLAIMED
# 10469499              le long de la Coulée-Grou:  [UNCLAIMED]     UNCLAIMED
# 10185142        Montée Gagnon to Saint Francois:  [UNCLAIMED]     UNCLAIMED
# 10346477    Rue de Plaisance / Rue Sylvain Meunier:  [UNCL...     UNCLAIMED
# 10623568            Vieux Chemin St-Charles Est:  [UNCLAIMED]     UNCLAIMED
# 10623573    OLD VERSION - Vieux Chemin St-Charles Ouest:  ...     UNCLAIMED
# 10469484    Longer la 40 dans les bois du parc nature:  [U...     UNCLAIMED
# 10469512    Gouin à Gouin via le Parc Nature RDP:  [UNCLAI...     UNCLAIMED
# 10347137                            Un tour PMG:  [UNCLAIMED]     UNCLAIMED
# 10349005            Défi Casse-Tête 2015 - tour:  [UNCLAIMED]     UNCLAIMED
# 10842995                Le tour de l'île Haynes:  [UNCLAIMED]     UNCLAIMED
# 10290118           Sprint Louis-Joseph Papineau:  [UNCLAIMED]     UNCLAIMED
# 10348320                   Defi Casse-Tete 2015:  [UNCLAIMED]     UNCLAIMED
# 10347396                        Defi Casse-Tête:  [UNCLAIMED]     UNCLAIMED
# 10250291            Sprint Céloron - des Liards:  [UNCLAIMED]     UNCLAIMED
# 11073761                   Lap winter race 2015:  [UNCLAIMED]     UNCLAIMED
# 10249873                        Pont le Gardeur:  [UNCLAIMED]     UNCLAIMED
# 10346424             Boulevard de la pininère O:  [UNCLAIMED]     UNCLAIMED
# 10639232                      Parc de la Coulée:  [UNCLAIMED]     UNCLAIMED
# 10346530    Boulevard Des Seigneurs / Rue Beauvais:  [UNCL...     UNCLAIMED
# 10346565    École Trois-Saisons / Boulevard Des Seigneurs:...     UNCLAIMED
# 10482772                    Boul de la Rochelle:  [UNCLAIMED]     UNCLAIMED
# 11047612                       edge vers le sud:  [UNCLAIMED]     UNCLAIMED
#
#              color                                       segment_name  \
# segment_id
# 3655223     000000                                Boul. Pincourt hill
# 4373377     000000                                     Pincourt Punch
# 8840701     000000                                      Full fat loop
# 9349111     000000           Boul. Pincourt bike path + rue du Rocher
# 821292      9CD0EF                                        Dave's hill
# 4305613     9CD0EF                                        Warp Dragon
# 2492803     9CD0EF                             Senneville Hill - West
# 2196976     9CD0EF                                   Senneville Climb
# 1019465     9CD0EF                                         Apple Muur
# 7050243     9CD0EF                                    Dave'hill court
# 7778864     9CD0EF                 WCG : Interval 7 : Senneville Hill
# 2188255     9CD0EF                                         GLOCK MUUR
# 9316675     9CD0EF                          PS40 : KOM 3 : Senneville
# 9772929     9CD0EF                                        hilly billy
# 5003401     000000                                      Oka E-O / O-E
# 9451251     000000  Oka Square Loop (North) via Montee du Village ...
# 4530219     000000                Sprint final vers la cabane a sucre
# 4035578     000000           lalande-bois de rivière-freniere-lalande
# 7180817     000000                      Loop Saint et Ange "Official"
# 9910818     000000                     Petit Sprint de belle asphalte
# 4616988     000000                                      The Mira Hood
# 5624984     000000                                Ile Perrot Warm-up!
# 7930686     000000                                      Nitrous Oxide
# 4302537     000000                                    Traversier Trot
# 7605315     000000                             Blvd Perrot East 1.5km
# 7733739     000000  WCG : Ferries Loop : Terrasse Sprint : 7e to T...
# 9490953     000000                       la 20 jusquau chemin Duhamel
# 7264173     000000                                     LT Power-Climb
# 9625097     1D6914                 Autoroute 20 : Ile-Perot→Vaudreuil
# 4791945     000000                      Rue de l'Hôtel de Ville Climb
# ...            ...                                                ...
# 10469430    000000                       La boucle du Parc nature sud
# 10185152    000000                                        Paul Albert
# 10622821    000000                                       Test Vitesse
# 11153275    000000                             dans le champ de la 40
# 10288544    000000                                          Lala loop
# 11153264    000000                       dans le champ de la 40 ouest
# 10324310    000000                                          Pama loop
# 8109705     000000                                     Tour Est Laval
# 10469499    000000                          le long de la Coulée-Grou
# 10185142    000000                    Montée Gagnon to Saint Francois
# 10346477    000000             Rue de Plaisance / Rue Sylvain Meunier
# 10623568    000000                        Vieux Chemin St-Charles Est
# 10623573    000000        OLD VERSION - Vieux Chemin St-Charles Ouest
# 10469484    000000          Longer la 40 dans les bois du parc nature
# 10469512    000000               Gouin à Gouin via le Parc Nature RDP
# 10347137    000000                                        Un tour PMG
# 10349005    000000                        Défi Casse-Tête 2015 - tour
# 10842995    000000                            Le tour de l'île Haynes
# 10290118    000000                       Sprint Louis-Joseph Papineau
# 10348320    000000                               Defi Casse-Tete 2015
# 10347396    000000                                    Defi Casse-Tête
# 10250291    000000                        Sprint Céloron - des Liards
# 11073761    000000                               Lap winter race 2015
# 10249873    000000                                    Pont le Gardeur
# 10346424    000000                         Boulevard de la pininère O
# 10639232    000000                                  Parc de la Coulée
# 10346530    000000             Boulevard Des Seigneurs / Rue Beauvais
# 10346565    000000      École Trois-Saisons / Boulevard Des Seigneurs
# 10482772    000000                                Boul de la Rochelle
# 11047612    000000                                   edge vers le sud
#
#                                                          url
# segment_id
# 3655223      http://www.strava.com/segments/3655223/compare/
# 4373377      http://www.strava.com/segments/4373377/compare/
# 8840701      http://www.strava.com/segments/8840701/compare/
# 9349111      http://www.strava.com/segments/9349111/compare/
# 821292        http://www.strava.com/segments/821292/compare/
# 4305613      http://www.strava.com/segments/4305613/compare/
# 2492803      http://www.strava.com/segments/2492803/compare/
# 2196976      http://www.strava.com/segments/2196976/compare/
# 1019465      http://www.strava.com/segments/1019465/compare/
# 7050243      http://www.strava.com/segments/7050243/compare/
# 7778864      http://www.strava.com/segments/7778864/compare/
# 2188255      http://www.strava.com/segments/2188255/compare/
# 9316675      http://www.strava.com/segments/9316675/compare/
# 9772929      http://www.strava.com/segments/9772929/compare/
# 5003401      http://www.strava.com/segments/5003401/compare/
# 9451251      http://www.strava.com/segments/9451251/compare/
# 4530219      http://www.strava.com/segments/4530219/compare/
# 4035578      http://www.strava.com/segments/4035578/compare/
# 7180817      http://www.strava.com/segments/7180817/compare/
# 9910818      http://www.strava.com/segments/9910818/compare/
# 4616988      http://www.strava.com/segments/4616988/compare/
# 5624984      http://www.strava.com/segments/5624984/compare/
# 7930686      http://www.strava.com/segments/7930686/compare/
# 4302537      http://www.strava.com/segments/4302537/compare/
# 7605315      http://www.strava.com/segments/7605315/compare/
# 7733739      http://www.strava.com/segments/7733739/compare/
# 9490953      http://www.strava.com/segments/9490953/compare/
# 7264173      http://www.strava.com/segments/7264173/compare/
# 9625097      http://www.strava.com/segments/9625097/compare/
# 4791945      http://www.strava.com/segments/4791945/compare/
# ...                                                      ...
# 10469430    http://www.strava.com/segments/10469430/compare/
# 10185152    http://www.strava.com/segments/10185152/compare/
# 10622821    http://www.strava.com/segments/10622821/compare/
# 11153275    http://www.strava.com/segments/11153275/compare/
# 10288544    http://www.strava.com/segments/10288544/compare/
# 11153264    http://www.strava.com/segments/11153264/compare/
# 10324310    http://www.strava.com/segments/10324310/compare/
# 8109705      http://www.strava.com/segments/8109705/compare/
# 10469499    http://www.strava.com/segments/10469499/compare/
# 10185142    http://www.strava.com/segments/10185142/compare/
# 10346477    http://www.strava.com/segments/10346477/compare/
# 10623568    http://www.strava.com/segments/10623568/compare/
# 10623573    http://www.strava.com/segments/10623573/compare/
# 10469484    http://www.strava.com/segments/10469484/compare/
# 10469512    http://www.strava.com/segments/10469512/compare/
# 10347137    http://www.strava.com/segments/10347137/compare/
# 10349005    http://www.strava.com/segments/10349005/compare/
# 10842995    http://www.strava.com/segments/10842995/compare/
# 10290118    http://www.strava.com/segments/10290118/compare/
# 10348320    http://www.strava.com/segments/10348320/compare/
# 10347396    http://www.strava.com/segments/10347396/compare/
# 10250291    http://www.strava.com/segments/10250291/compare/
# 11073761    http://www.strava.com/segments/11073761/compare/
# 10249873    http://www.strava.com/segments/10249873/compare/
# 10346424    http://www.strava.com/segments/10346424/compare/
# 10639232    http://www.strava.com/segments/10639232/compare/
# 10346530    http://www.strava.com/segments/10346530/compare/
# 10346565    http://www.strava.com/segments/10346565/compare/
# 10482772    http://www.strava.com/segments/10482772/compare/
# 11047612    http://www.strava.com/segments/11047612/compare/
#
# [2663 rows x 8 columns]

# %%
from WarReportLogger import main_logger
try:
    main_logger(df2,df1)
except Exception as e:
    print 'Error: '+str(e)
    pass
# Out:
# Error: Can only compare identically-labeled DataFrame objects

# %%
#df_holdings['marketValueUSD'][df_holdings['currency'] == 'USD'] = df_holdings['marketValue']
#merged_left_regions['Canada'][(merged_left_regions['sub type'] == 'Bond') & (merged_left_regions['currency'] == 'CAD')] = 100
df2['type'][df2.index == 821292] = 'Mike Sants'
df2['color'][df2.index == 821292] = '1D6914'
df2['type'][df2.index == 4571910] = 'Mike Sants'
df2['color'][df2.index == 4571910] = '1D6914'
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
now = datetime.datetime.now()

#don't understand the following block of code:
ne = (df1 != df2).any(1)
ne_stacked = (df1 != df2).stack()
changed = ne_stacked[ne_stacked]
difference_locations = np.where(df1 != df2)
changed_from = df1.values[difference_locations]
changed_to = df2.values[difference_locations]
changed_df = pd.DataFrame({'from': changed_from, 'to': changed_to}, index=changed.index)

changed_df2 = changed_df.unstack() 
# its making some sort of multi-index array but I can't figure out how to slice or work with the data.  Unstack atleast gets
#it back into a form I can work with but this seems very inefficient, need to figure out how to work with multi-index df

changed_from2 = changed_df2['from']['type']
changed_to2 = changed_df2['to']['type']

df_changed_from = pd.DataFrame(changed_from2)
df_changed_from = df_changed_from[df_changed_from.type.notnull()]

df_changed_to = pd.DataFrame(changed_to2)
df_changed_to = df_changed_to[df_changed_to.type.notnull()]


war_report_dict = {}
for x in df_changed_to['type'].unique():

    personcount = defaultdict(int)

    for y in df_changed_to[df_changed_to['type'] == x].index:

        #don't get why the output here is a numpy array:
        beatperson_array = df_changed_from[df_changed_from.index == y].values[0]

        #converting to string:
        beatperson_string = str(beatperson_array[0])

        personcount[beatperson_string] += 1

    war_report_dict[x] = personcount



logfile=open('warlog.csv', 'a+')

for warlord in war_report_dict:
    for victim in sorted(war_report_dict[warlord].items(), key=operator.itemgetter(1), reverse=True):
        if victim[0] == 'UNCLAIMED':
            if victim[1] == 1:
                print warlord,'claimed',victim[1],'unowned territory'
                line = str(now)+','+warlord+' claimed '+str(victim[1])+' unowned territory,NO'
            else:
                print warlord,'claimed',victim[1],'unowned territories'
                line = str(now)+','+warlord+' claimed '+str(victim[1])+' unowned territories,NO'
        else:
            if victim[1] == 1:
                print warlord,'conquered',victim[1],'territory from',victim[0]
                line = str(now)+','+warlord+' conquered '+str(victim[1])+' territory from '+victim[0]+',NO'
            else:
                print warlord,'conquered',victim[1],'territories from',victim[0]
                line = str(now)+','+warlord+' conquered '+str(victim[1])+' territories from '+victim[0]+',NO'
        logfile.write(line+'\n') 
logfile.close()
# Out:
# Frank Oduro claimed 18 unowned territories
# Frank Oduro conquered 2 territories from Laurie McQueen
# Frank Oduro conquered 1 territory from Arvind Ramanathan
# Vincent Trudel-Lapierre conquered 1 territory from Laurie McQueen
# Vincent Trudel-Lapierre claimed 1 unowned territory
# Vitor Lima claimed 7 unowned territories
# Vitor Lima conquered 2 territories from Yibing Wen
# Vitor Lima conquered 1 territory from Mario Born
# Vitor Lima conquered 1 territory from Josh Felker

# %%
a = "text1"
b = "texst2"
logfile=open('warlog.csv', 'a+')
line = ""
line = 'testdate,'+a+' claimed '+b+' unowned territory,NO'
print 'testdate,',a,'claimed',b,'unowned territory,NO'
print line
logfile.write(line+'\n')
# Out:
# testdate, text1 claimed texst2 unowned territory,NO
# testdate,text1 claimed texst2 unowned territory,NO

# %%
changed_type = (df1.type != df2.type)

# %%
ne = (df1.type != df2.type)
ne_stacked = (df1 != df2).stack()
changed = ne_stacked[ne_stacked]
changed
# Out:
# segment_id
# 821292      type            True
#             color           True
# 4571910     segment_name    True
# 3795805     segment_name    True
# 1216650     segment_name    True
# dtype: bool
